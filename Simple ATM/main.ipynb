# %%
again = "Y"
balance = 0

print("Welcome to Sullivan Bank")

while again == "Y":
    
    print("Please choose from the following options")
    print("     1. Make a deposit")
    print("     2. Make a withdraw")
    print("     3. Get balance information")
    print("     4. Exit")
    choice=int(input("What would you like to do?  "))
    
    if choice == 1 and balance ==0:
        print("Your current balance is $0.00")
        d=float(input("How much would you like to deposit? "))
        if d >= 100:
            balance+=d
            print("Your current balance is $", balance)
            another=input("Do you want to make another deposit?(Y/N) ").upper()
            while another == "Y":
#                 more == True
#                 while more == True:
                print("Your current balance is $", balance)
                d=float(input("How much would you like to deposit? "))
                balance+=d
                print("Your new balance is $", balance)
                another=input("Do you want to make another deposit?(Y/N) ").upper()
#                     if another == "Y":
#                         more == True
#                     else:
#                         more == False
            again=input("Would you like to perform another transaction?(Y/N) ").upper()
#         else:
#             again=input("Would you like to perform another transaction?(Y/N) ").upper()
#             print("To fund your account, your deposit must be $100 or greater.")
#             d=float(input("How much would you like to deposit? "))
#             again  =input("Would you like to perform another transaction?(Y/N) ").upper()
                
        else:
            insufficient = True
            while insufficient == True:
                #print("To fund your account, your deposit must be $100 or greater.")
                d=float(input("How much would you like to deposit? "))
                if d < 100:
                    insufficient = True
                else:
                    insufficient = False
                    balance+=d
                    print("Your current balance is $", balance)
                    another=input("Do you want to make another deposit?(Y/N) ").upper()
#                     more = True
                    while another == 'Y':
                        print("Your current balance is $", balance)
                        d=float(input("How much would you like to deposit? "))
                        balance+=d
                        print("Your new balance is $", balance)
                        another=input("Do you want to make another deposit?(Y/N) ").upper()
#                         if another1 == "Y":
#                             more == True
#                         else:
#                             more == False
            again=input("Would you like to perform another transaction?(Y/N) ").upper()
#             else another == "N":
#                 again=input("Would you like to perform another transaction?(Y/N) ").upper()
                                       
    elif choice == 1 and balance > 0:
#         more = True
            print("Your current balance is $", balance)
            d = float(input("How much would you like to deposit? "))
            balance+=d
            print("Your new balance is $", balance)
            another = input("Do you want to make another deposit?(Y/N) ").upper()
            while another == 'Y':
                print("Your current balance is $", balance)
                d = float(input("How much would you like to deposit? "))
                balance+=d
                print("Your new balance is $", balance)
                another = input("Do you want to make another deposit?(Y/N) ").upper()
#             if another == "Y":
#                 another = True
#             else:
#                 another = False
            again=input("Would you like to perform another transaction?(Y/N) ").upper()

    elif choice == 2 and balance == 0:
        w=float(input("How much would you like to withdraw? "))
        print("Your account has insufficient funds.")
        print("Please make a deposit.")
        print("Your current balance is $", balance)
        again=input("Would you like to perform another transaction?(Y/N) ").upper()

    elif choice == 2 and balance > 0:
        another = True
        while another == True:
            w=float(input("How much would you like to withdraw? "))
            if w > balance:
                print("Overdraft! Insufficient funds to complete transaction")
            elif w < balance:
                print("Your current balance is $", balance)
                balance-=w
                print("Your new balance is $", balance)
                another1 = input("Do you want to make another withdrawal?(Y/N) ").upper()
                if another1 == "Y":
                    another = True
                else:
                    another = False
                    again=input("Would you like to perform another transaction?(Y/N) ").upper()
            else:
                balance-=w
                print("Your current balance is $", balance)
                another = False
                again=input("Would you like to perform another transaction?(Y/N) ").upper()
                
    elif choice == 3:
        print("Your current balance is $", balance)
        again=input("Would you like to perform another transaction?(Y/N) ").upper()
        
    elif choice == 4:
        print("Thank you for choosing Sullivan Bank")
        print("        Goodbye!      ")
        break
# Out:
# Welcome to Sullivan Bank
# Please choose from the following options
#      1. Make a deposit
#      2. Make a withdraw
#      3. Get balance information
#      4. Exit
# What would you like to do?  2
# How much would you like to withdraw? 100
# Your account has insufficient funds.
# Please make a deposit.
# Your current balance is $ 0
# Would you like to perform another transaction?(Y/N) y
# Please choose from the following options
#      1. Make a deposit
#      2. Make a withdraw
#      3. Get balance information
#      4. Exit
# What would you like to do?  3
# Your current balance is $ 0
# Would you like to perform another transaction?(Y/N) y
# Please choose from the following options
#      1. Make a deposit
#      2. Make a withdraw
#      3. Get balance information
#      4. Exit
# What would you like to do?  1
# Your current balance is $0.00
# How much would you like to deposit? 10
# How much would you like to deposit? 10
# How much would you like to deposit? 1000
# ...
