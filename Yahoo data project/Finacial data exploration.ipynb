# %% [markdown]
# Install yfinance

# %%
pip install yfinance

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
# %matplotlib notebook

# %%
# stock_list = ['0005.HK', '0006.HK', '0066.HK', '0700.HK', '2800.HK']
# print(stock_list)

# %%
# stocks = [yf.Tickers(input("Please select stock ticker symbol: ").upper()), '^GSPC']
# print(stocks)

# data = yf.download(stocks, start="2019-01-01", end="2019-12-31")
# print('data fields downloaded:', set(data.columns.get_level_values(0)))
# data.head()

# %%
#Get user ticker symbol
#Return ticker head and counts 
#Return S&P head and counts
ticker = yf.Ticker(input("Please select stock ticker symbol: ").upper())
def get_info(ticker):
    # ticker = yf.Ticker(input("Please select stock ticker symbol: ").upper())
    print(ticker)
    # print(ticker.info)
    hist=ticker.history(start="2019-01-01", end="2019-12-31")
    SP=yf.Ticker("^GSPC")
    print(SP)
    SP_hist=ticker.history(start="2019-01-01", end="2019-12-31")
    # stock = ticker
    # data = yf.download(stock, start="2019-01-01", end="2019-12-31")
    return ticker, hist.head(),hist.info(), SP, SP_hist.head(),SP_hist.info()
    
get_info(ticker)

# %%
msft = yf.Ticker("MSFT")
msft.info

# %%
msft_hist = msft.history(period="max")
msft_hist

# %%
#2- Processing Data
microsoft_daily_change = 'MSFT'['Close'].pct_change()
sp_daily_change ='^GSPC'['Close'].pct_change()
print(microsoft_daily_change.head())
print(sp_daily_change.head())

# %%
fig = plt.figure()
ax1 = fig.add_axes([0.1,0.1,1,1])
ax1.plot(microsoft_daily_change)
ax1.set_xlabel("Date")
ax1.set_ylabel("Percent")
ax1.set_title("Microsoft daily % change")
plt.show()

# %%
print(microsoft_daily_change.mean())
print(sp_daily_change.mean())
print(microsoft_daily_change.std())
print(sp_daily_change.std())
print(microsoft_daily_change.var())
print(sp_daily_change.var())
print(min(microsoft_daily_change))
print(min(sp_daily_change))
print(max(microsoft_daily_change))
print(max(sp_daily_change))

# %%
#Question 3
msft = yf.Ticker("MSFT")
msft.info
msft_data = yf.download("MSFT", start="2019-01-01", end="2019-12-31")

SP = yf.Ticker("^GSPC")
SP_data = yf.download("^GSPC", start="2019-01-01", end="2019-12-31")


msft_hist = msft.history(start = "2019-01-01", end="2019-12-31")
msft_df = pd.DataFrame(msft_hist)

SP_hist = SP.history(start = "2019-01-01", end="2019-12-31")
SP_df = pd.DataFrame(SP_hist, column = [Adj Close])

plt.scatter(msft_df, SP_df)
plt.title('Regression Analysis')
plt.xlabel('Microsoft')
plt.ylabel('S and P 500')
plt.grid(True)
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# <img src="data:image/png;base64,..." width="640">

# %%
X = msft_df
Y = SP_df

regr = linear_model.LinearRegression()
regr.fit(X, Y)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)
